# %% [markdown]
# # Projet 7 - Implémentez un modèle de scoring
# Utilisation d'un Kernel pour gagner du temps sur le préprocessing et le feature engineering du dataset.
# ## Imports

# %%
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import f1_score, roc_auc_score, roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import KFold, StratifiedKFold, learning_curve
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_row', 800)

# %% [markdown]
# ## Accès aux données

# %%
chemin = "G:/Mon Drive/Yann Pham-Van - Data Scientist - OpenClassrooms/Projet7-Implémentez un modèle de scoring/input/"

# %% [markdown]
# ## Fonctions

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv(chemin+'application_train.csv', nrows= num_rows)
    test_df = pd.read_csv(chemin+'application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    # df = df.append(test_df).reset_index()
    df = pd.concat([df, test_df], ignore_index=True)
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']
    
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
    # Some simple new features (percentages)
    df['DAYS_EMPLOYED_PERC'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['INCOME_CREDIT_PERC'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']
    df['INCOME_PER_PERSON'] = df['AMT_INCOME_TOTAL'] / df['CNT_FAM_MEMBERS']
    df['ANNUITY_INCOME_PERC'] = df['AMT_ANNUITY'] / df['AMT_INCOME_TOTAL']
    df['PAYMENT_RATE'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']
    del test_df
    gc.collect()
    return df

# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv(chemin+'bureau.csv', nrows = num_rows)
    bb = pd.read_csv(chemin+'bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
    
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# Preprocess previous_applications.csv
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv(chemin+'previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'APP_CREDIT_PERC': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# Preprocess POS_CASH_balance.csv
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv(chemin+'POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg
    
# Preprocess installments_payments.csv
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv(chemin+'installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': ['max', 'mean', 'sum', 'var'],
        'PAYMENT_DIFF': ['max', 'mean', 'sum', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv(chemin+'credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# Séparation du dataframe en train et test
def train_test_cleaned(df):
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Dataframe avec target shape: {}, dataframe sans target shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    return train_df, test_df

# Fonction principale appelant les fonctions précédentes
def main(debug = False):
    num_rows = 10000 if debug else None
    df = application_train_test(num_rows)
    with timer("Process bureau and bureau_balance"):
        bureau = bureau_and_balance(num_rows)
        print("Bureau df shape:", bureau.shape)
        df = df.join(bureau, how='left', on='SK_ID_CURR')
        del bureau
        gc.collect()
    with timer("Process previous_applications"):
        prev = previous_applications(num_rows)
        print("Previous applications df shape:", prev.shape)
        df = df.join(prev, how='left', on='SK_ID_CURR')
        del prev
        gc.collect()
    with timer("Process POS-CASH balance"):
        pos = pos_cash(num_rows)
        print("Pos-cash balance df shape:", pos.shape)
        df = df.join(pos, how='left', on='SK_ID_CURR')
        del pos
        gc.collect()
    with timer("Process installments payments"):
        ins = installments_payments(num_rows)
        print("Installments payments df shape:", ins.shape)
        df = df.join(ins, how='left', on='SK_ID_CURR')
        del ins
        gc.collect()
    with timer("Process credit card balance"):
        cc = credit_card_balance(num_rows)
        print("Credit card balance df shape:", cc.shape)
        df = df.join(cc, how='left', on='SK_ID_CURR')
        del cc
        gc.collect()
    with timer("Séparation du dataframe en dataframe avec target pour la modélisation et sans target pour les tests finaux"):
        df_train, df_test = train_test_cleaned(df)
    return df_train, df_test

# %% [markdown]
# ## Lancement du kernel

# %%
with timer("______________________________________________________________________\nFull préprocessing & Feature engineering"):
    data_model, data_sans_target = main()
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 116)
# Process bureau and bureau_balance - done in 12s
# Previous applications df shape: (338857, 249)
# Process previous_applications - done in 12s
# Pos-cash balance df shape: (337252, 18)
# Process POS-CASH balance - done in 7s
# Installments payments df shape: (339587, 26)
# Process installments payments - done in 18s
# Credit card balance df shape: (103558, 141)
# Process credit card balance - done in 9s
# Dataframe avec target shape: (307507, 797), dataframe sans target shape: (48744, 797)
# Séparation du dataframe en dataframe avec target pour la modélisation et sans target pour les tests finaux - done in 1s
# ______________________________________________________________________
# Full préprocessing & Feature engineering - done in 61s

# %% [markdown]
# ## Observations préliminaires

# %%
df = data_model.copy()

# %%
df.shape
# Out:
# (307507, 797)

# %%
df.head(5)
# Out:
#    SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      100002     1.0            0             0                0
# 1      100003     0.0            1             0                1
# 2      100004     0.0            0             1                0
# 3      100006     0.0            1             0                0
# 4      100007     0.0            0             0                0
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          202500.0    406597.5      24700.5         351000.0
# 1             0          270000.0   1293502.5      35698.5        1129500.0
# 2             0           67500.0    135000.0       6750.0         135000.0
# 3             0          135000.0    312682.5      29686.5         297000.0
# 4             0          121500.0    513000.0      21865.5         513000.0
#
#    ...  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0  ...                                 NaN
# 1  ...                                 NaN
# 2  ...                                 NaN
# 3  ...                               False
# 4  ...                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  0.0                                 0.0
# 4                                  NaN                                 NaN
#
#    CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 0.0                            False
# 4                                 NaN                              NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                            False                               0.0
# 4                              NaN                               NaN
#
#    CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN                              NaN       NaN
# 1                              NaN                              NaN       NaN
# 2                              NaN                              NaN       NaN
# 3                              0.0                              0.0       6.0
# 4                              NaN                              NaN       NaN
#
# [5 rows x 797 columns]

# %%
df.tail(5)
# Out:
#         SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 307506      456251     0.0            0             0                1
# 307507      456252     0.0            1             0                0
# 307508      456253     0.0            1             0                0
# 307509      456254     1.0            1             0                0
# 307510      456255     0.0            1             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 307506             0          157500.0    254700.0      27558.0
# 307507             0           72000.0    269550.0      12001.5
# 307508             0          153000.0    677664.0      29979.0
# 307509             0          171000.0    370107.0      20205.0
# 307510             0          157500.0    675000.0      49117.5
#
#         AMT_GOODS_PRICE  ...  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 307506         225000.0  ...                                 NaN
# 307507         225000.0  ...                                 NaN
# 307508         585000.0  ...                                 NaN
# 307509         319500.0  ...                                 NaN
# 307510         675000.0  ...                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 307506                                  NaN
# 307507                                  NaN
# 307508                                  NaN
# 307509                                  NaN
# 307510                                  NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 307506                                 NaN
# 307507                                 NaN
# 307508                                 NaN
# 307509                                 NaN
# 307510                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 307506                                 NaN                              NaN
# 307507                                 NaN                              NaN
# 307508                                 NaN                              NaN
# 307509                                 NaN                              NaN
# 307510                                 NaN                              NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 307506                              NaN                               NaN
# 307507                              NaN                               NaN
# 307508                              NaN                               NaN
# 307509                              NaN                               NaN
# 307510                              NaN                               NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  \
# 307506                              NaN                              NaN
# 307507                              NaN                              NaN
# 307508                              NaN                              NaN
# 307509                              NaN                              NaN
# 307510                              NaN                              NaN
#
#         CC_COUNT
# 307506       NaN
# 307507       NaN
# 307508       NaN
# 307509       NaN
# 307510       NaN
#
# [5 rows x 797 columns]

# %%
df.sample(5)
# Out:
#         SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 126122      246254     0.0            0             0                0
# 184272      313585     0.0            1             1                0
# 159236      284601     0.0            0             1                0
# 23788       127678     0.0            0             1                1
# 161438      287154     0.0            1             0                0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 126122             0          202500.0    540000.0      27000.0
# 184272             0          247500.0   1327500.0      50562.0
# 159236             1          112500.0    544491.0      17694.0
# 23788              2          157500.0    728460.0      40675.5
# 161438             0          112500.0   1181016.0      38227.5
#
#         AMT_GOODS_PRICE  ...  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 126122         540000.0  ...                                 NaN
# 184272        1327500.0  ...                               False
# 159236         454500.0  ...                               False
# 23788          675000.0  ...                                 NaN
# 161438         846000.0  ...                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# 126122                                  NaN
# 184272                                  0.0
# 159236                                  0.0
# 23788                                   NaN
# 161438                                  NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 126122                                 NaN
# 184272                                 0.0
# 159236                                 0.0
# 23788                                  NaN
# 161438                                 NaN
#
#         CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 126122                                 NaN                              NaN
# 184272                                 0.0                            False
# 159236                                 0.0                            False
# 23788                                  NaN                              NaN
# 161438                                 NaN                              NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 126122                              NaN                               NaN
# 184272                            False                               0.0
# 159236                            False                               0.0
# 23788                               NaN                               NaN
# 161438                              NaN                               NaN
#
#         CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  \
# 126122                              NaN                              NaN
# 184272                              0.0                              0.0
# 159236                              0.0                              0.0
# 23788                               NaN                              NaN
# 161438                              NaN                              NaN
#
#         CC_COUNT
# 126122       NaN
# 184272      13.0
# 159236      10.0
# 23788        NaN
# 161438       NaN
#
# [5 rows x 797 columns]

# %%
# Nombre de colonnes selon type de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307507 entries, 0 to 307510
# Columns: 797 entries, SK_ID_CURR to CC_COUNT
# dtypes: bool(133), float64(606), int64(42), object(16)
# memory usage: 1.6+ GB

# %%
df.dtypes.value_counts()
# Out:
# float64    606
# bool       133
# int64       42
# object      16
# Name: count, dtype: int64

# %%
# Taux de manquants par colonnes
df.isna().mean().sort_values(ascending=False)
# Out:
# REFUSED_AMT_DOWN_PAYMENT_MAX                                             0.853116
# REFUSED_AMT_DOWN_PAYMENT_MEAN                                            0.853116
# REFUSED_AMT_DOWN_PAYMENT_MIN                                             0.853116
# REFUSED_RATE_DOWN_PAYMENT_MEAN                                           0.853116
# REFUSED_RATE_DOWN_PAYMENT_MAX                                            0.853116
# REFUSED_RATE_DOWN_PAYMENT_MIN                                            0.853116
# REFUSED_APP_CREDIT_PERC_VAR                                              0.840143
# CC_AMT_PAYMENT_CURRENT_VAR                                               0.802870
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                                          0.802629
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                                        0.802629
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                                        0.802629
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                                          0.802629
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                                          0.802629
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                                          0.802629
# CC_AMT_PAYMENT_CURRENT_MEAN                                              0.801435
# CC_AMT_PAYMENT_CURRENT_MAX                                               0.801435
# CC_AMT_PAYMENT_CURRENT_MIN                                               0.801435
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                                       0.801175
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                                        0.801175
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                                          0.801175
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                                          0.801175
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                                         0.801175
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                                         0.801175
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                                          0.801175
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                                          0.801175
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                                          0.801175
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                                        0.801175
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                                        0.801175
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                                       0.801175
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                                         0.801175
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                                        0.801175
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                                          0.801175
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                                          0.801175
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                                          0.801175
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                                         0.801175
# ACTIVE_AMT_ANNUITY_MEAN                                                  0.800505
# ACTIVE_AMT_ANNUITY_MAX                                                   0.800505
# CLOSED_AMT_ANNUITY_MAX                                                   0.785341
# CLOSED_AMT_ANNUITY_MEAN                                                  0.785341
# ACTIVE_MONTHS_BALANCE_MAX_MAX                                            0.751163
# ACTIVE_MONTHS_BALANCE_MIN_MIN                                            0.751163
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN                                          0.751163
# BURO_AMT_ANNUITY_MAX                                                     0.739814
# BURO_AMT_ANNUITY_MEAN                                                    0.739814
# CLOSED_MONTHS_BALANCE_SIZE_MEAN                                          0.737453
# CLOSED_MONTHS_BALANCE_MAX_MAX                                            0.737453
# CLOSED_MONTHS_BALANCE_MIN_MIN                                            0.737453
# CC_SK_DPD_VAR                                                            0.719444
# CC_AMT_BALANCE_VAR                                                       0.719444
# CC_NAME_CONTRACT_STATUS_Refused_VAR                                      0.719444
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                                         0.719444
# CC_AMT_TOTAL_RECEIVABLE_VAR                                              0.719444
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                                         0.719444
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                                          0.719444
# CC_SK_DPD_DEF_VAR                                                        0.719444
# CC_NAME_CONTRACT_STATUS_Approved_VAR                                     0.719444
# CC_AMT_RECIVABLE_VAR                                                     0.719444
# CC_AMT_INST_MIN_REGULARITY_VAR                                           0.719444
# CC_CNT_DRAWINGS_CURRENT_VAR                                              0.719444
# CC_NAME_CONTRACT_STATUS_Active_VAR                                       0.719444
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                                0.719444
# CC_MONTHS_BALANCE_VAR                                                    0.719444
# CC_NAME_CONTRACT_STATUS_nan_VAR                                          0.719444
# CC_NAME_CONTRACT_STATUS_Demand_VAR                                       0.719444
# CC_NAME_CONTRACT_STATUS_Signed_VAR                                       0.719444
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                                           0.719444
# CC_AMT_DRAWINGS_CURRENT_VAR                                              0.719444
# CC_NAME_CONTRACT_STATUS_Completed_VAR                                    0.719444
# CC_AMT_BALANCE_MEAN                                                      0.717389
# CC_AMT_TOTAL_RECEIVABLE_MAX                                              0.717389
# CC_AMT_TOTAL_RECEIVABLE_MEAN                                             0.717389
# CC_AMT_TOTAL_RECEIVABLE_SUM                                              0.717389
# CC_MONTHS_BALANCE_MIN                                                    0.717389
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                                        0.717389
# CC_CNT_DRAWINGS_CURRENT_SUM                                              0.717389
# CC_AMT_BALANCE_MAX                                                       0.717389
# CC_AMT_TOTAL_RECEIVABLE_MIN                                              0.717389
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                                          0.717389
# CC_AMT_BALANCE_MIN                                                       0.717389
# CC_CNT_DRAWINGS_CURRENT_MIN                                              0.717389
# CC_CNT_DRAWINGS_CURRENT_MAX                                              0.717389
# CC_MONTHS_BALANCE_MEAN                                                   0.717389
# CC_MONTHS_BALANCE_SUM                                                    0.717389
# CC_CNT_DRAWINGS_CURRENT_MEAN                                             0.717389
# CC_MONTHS_BALANCE_MAX                                                    0.717389
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                                          0.717389
# CC_AMT_RECIVABLE_SUM                                                     0.717389
# CC_AMT_RECIVABLE_MEAN                                                    0.717389
# CC_AMT_DRAWINGS_CURRENT_MIN                                              0.717389
# CC_AMT_DRAWINGS_CURRENT_MAX                                              0.717389
# CC_AMT_DRAWINGS_CURRENT_MEAN                                             0.717389
# CC_AMT_DRAWINGS_CURRENT_SUM                                              0.717389
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                                        0.717389
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                                           0.717389
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                                          0.717389
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                                          0.717389
# CC_AMT_INST_MIN_REGULARITY_MIN                                           0.717389
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                                           0.717389
# CC_AMT_INST_MIN_REGULARITY_MEAN                                          0.717389
# CC_AMT_INST_MIN_REGULARITY_SUM                                           0.717389
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                                           0.717389
# CC_AMT_PAYMENT_CURRENT_SUM                                               0.717389
# CC_AMT_BALANCE_SUM                                                       0.717389
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                                         0.717389
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                                         0.717389
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                                        0.717389
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                                         0.717389
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                                          0.717389
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                                          0.717389
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                                         0.717389
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                                          0.717389
# CC_AMT_RECIVABLE_MIN                                                     0.717389
# CC_AMT_RECIVABLE_MAX                                                     0.717389
# CC_AMT_INST_MIN_REGULARITY_MAX                                           0.717389
# CC_COUNT                                                                 0.717389
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                                          0.717389
# CC_NAME_CONTRACT_STATUS_Approved_SUM                                     0.717389
# CC_NAME_CONTRACT_STATUS_nan_MIN                                          0.717389
# CC_NAME_CONTRACT_STATUS_Signed_SUM                                       0.717389
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                                      0.717389
# CC_NAME_CONTRACT_STATUS_Signed_MAX                                       0.717389
# CC_NAME_CONTRACT_STATUS_Signed_MIN                                       0.717389
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                                0.717389
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                               0.717389
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                                0.717389
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                                0.717389
# CC_NAME_CONTRACT_STATUS_Refused_SUM                                      0.717389
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                                     0.717389
# CC_NAME_CONTRACT_STATUS_Refused_MAX                                      0.717389
# CC_NAME_CONTRACT_STATUS_Refused_MIN                                      0.717389
# CC_NAME_CONTRACT_STATUS_Demand_SUM                                       0.717389
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                                      0.717389
# CC_NAME_CONTRACT_STATUS_Demand_MAX                                       0.717389
# CC_NAME_CONTRACT_STATUS_Demand_MIN                                       0.717389
# CC_NAME_CONTRACT_STATUS_Completed_SUM                                    0.717389
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                                   0.717389
# CC_NAME_CONTRACT_STATUS_Completed_MIN                                    0.717389
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                                    0.717389
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                                         0.717389
# CC_NAME_CONTRACT_STATUS_Approved_MAX                                     0.717389
# CC_NAME_CONTRACT_STATUS_nan_SUM                                          0.717389
# CC_NAME_CONTRACT_STATUS_nan_MEAN                                         0.717389
# CC_NAME_CONTRACT_STATUS_nan_MAX                                          0.717389
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                                         0.717389
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                                        0.717389
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                                         0.717389
# CC_SK_DPD_MIN                                                            0.717389
# CC_SK_DPD_MAX                                                            0.717389
# CC_SK_DPD_MEAN                                                           0.717389
# CC_SK_DPD_SUM                                                            0.717389
# CC_SK_DPD_DEF_MIN                                                        0.717389
# CC_SK_DPD_DEF_MAX                                                        0.717389
# CC_SK_DPD_DEF_MEAN                                                       0.717389
# CC_SK_DPD_DEF_SUM                                                        0.717389
# CC_NAME_CONTRACT_STATUS_Active_MIN                                       0.717389
# CC_NAME_CONTRACT_STATUS_Active_MAX                                       0.717389
# CC_NAME_CONTRACT_STATUS_Active_MEAN                                      0.717389
# CC_NAME_CONTRACT_STATUS_Active_SUM                                       0.717389
# CC_NAME_CONTRACT_STATUS_Approved_MIN                                     0.717389
# CC_NAME_CONTRACT_STATUS_Completed_MAX                                    0.717389
# REFUSED_CNT_PAYMENT_MEAN                                                 0.702231
# REFUSED_AMT_ANNUITY_MEAN                                                 0.702231
# REFUSED_AMT_ANNUITY_MAX                                                  0.702231
# REFUSED_AMT_ANNUITY_MIN                                                  0.702231
# BURO_STATUS_0_MEAN_MEAN                                                  0.700069
# BURO_STATUS_X_MEAN_MEAN                                                  0.700069
# BURO_MONTHS_BALANCE_MIN_MIN                                              0.700069
# BURO_MONTHS_BALANCE_MAX_MAX                                              0.700069
# BURO_STATUS_nan_MEAN_MEAN                                                0.700069
# BURO_MONTHS_BALANCE_SIZE_MEAN                                            0.700069
# BURO_STATUS_3_MEAN_MEAN                                                  0.700069
# BURO_STATUS_1_MEAN_MEAN                                                  0.700069
# BURO_STATUS_5_MEAN_MEAN                                                  0.700069
# BURO_STATUS_4_MEAN_MEAN                                                  0.700069
# BURO_STATUS_C_MEAN_MEAN                                                  0.700069
# BURO_STATUS_2_MEAN_MEAN                                                  0.700069
# COMMONAREA_AVG                                                           0.698722
# COMMONAREA_MEDI                                                          0.698722
# COMMONAREA_MODE                                                          0.698722
# REFUSED_AMT_GOODS_PRICE_MAX                                              0.696823
# REFUSED_AMT_GOODS_PRICE_MEAN                                             0.696823
# REFUSED_AMT_GOODS_PRICE_MIN                                              0.696823
# NONLIVINGAPARTMENTS_MODE                                                 0.694332
# NONLIVINGAPARTMENTS_MEDI                                                 0.694332
# NONLIVINGAPARTMENTS_AVG                                                  0.694332
# REFUSED_APP_CREDIT_PERC_MEAN                                             0.689896
# REFUSED_APP_CREDIT_PERC_MIN                                              0.689893
# REFUSED_APP_CREDIT_PERC_MAX                                              0.689893
# LIVINGAPARTMENTS_AVG                                                     0.683552
# LIVINGAPARTMENTS_MODE                                                    0.683552
# LIVINGAPARTMENTS_MEDI                                                    0.683552
# FLOORSMIN_MEDI                                                           0.678489
# FLOORSMIN_MODE                                                           0.678489
# FLOORSMIN_AVG                                                            0.678489
# REFUSED_AMT_CREDIT_MEAN                                                  0.673861
# REFUSED_AMT_CREDIT_MAX                                                   0.673861
# REFUSED_AMT_CREDIT_MIN                                                   0.673861
# REFUSED_AMT_APPLICATION_MEAN                                             0.673861
# REFUSED_HOUR_APPR_PROCESS_START_MIN                                      0.673861
# REFUSED_HOUR_APPR_PROCESS_START_MAX                                      0.673861
# REFUSED_HOUR_APPR_PROCESS_START_MEAN                                     0.673861
# REFUSED_CNT_PAYMENT_SUM                                                  0.673861
# REFUSED_DAYS_DECISION_MIN                                                0.673861
# REFUSED_DAYS_DECISION_MAX                                                0.673861
# REFUSED_DAYS_DECISION_MEAN                                               0.673861
# REFUSED_AMT_APPLICATION_MIN                                              0.673861
# REFUSED_AMT_APPLICATION_MAX                                              0.673861
# YEARS_BUILD_AVG                                                          0.664980
# YEARS_BUILD_MEDI                                                         0.664980
# YEARS_BUILD_MODE                                                         0.664980
# OWN_CAR_AGE                                                              0.659910
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN                                       0.622652
# LANDAREA_MEDI                                                            0.593769
# LANDAREA_MODE                                                            0.593769
# LANDAREA_AVG                                                             0.593769
# BASEMENTAREA_MODE                                                        0.585164
# BASEMENTAREA_AVG                                                         0.585164
# BASEMENTAREA_MEDI                                                        0.585164
# EXT_SOURCE_1                                                             0.563812
# NONLIVINGAREA_AVG                                                        0.551792
# NONLIVINGAREA_MODE                                                       0.551792
# NONLIVINGAREA_MEDI                                                       0.551792
# ACTIVE_DAYS_CREDIT_VAR                                                   0.534830
# ELEVATORS_MEDI                                                           0.532963
# ELEVATORS_MODE                                                           0.532963
# ELEVATORS_AVG                                                            0.532963
# CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN                                       0.523468
# APARTMENTS_MEDI                                                          0.507501
# APARTMENTS_MODE                                                          0.507501
# APARTMENTS_AVG                                                           0.507501
# ENTRANCES_MODE                                                           0.503491
# ENTRANCES_MEDI                                                           0.503491
# ENTRANCES_AVG                                                            0.503491
# LIVINGAREA_MODE                                                          0.501937
# LIVINGAREA_MEDI                                                          0.501937
# LIVINGAREA_AVG                                                           0.501937
# FLOORSMAX_MEDI                                                           0.497611
# FLOORSMAX_MODE                                                           0.497611
# FLOORSMAX_AVG                                                            0.497611
# YEARS_BEGINEXPLUATATION_MODE                                             0.487813
# YEARS_BEGINEXPLUATATION_MEDI                                             0.487813
# YEARS_BEGINEXPLUATATION_AVG                                              0.487813
# TOTALAREA_MODE                                                           0.482688
# CLOSED_DAYS_CREDIT_VAR                                                   0.425522
# BURO_AMT_CREDIT_MAX_OVERDUE_MEAN                                         0.402023
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN                                         0.386277
# CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN                                         0.352964
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX                                           0.328438
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN                                          0.328438
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX                                           0.322998
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN                                           0.322998
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN                                          0.322998
# APPROVED_APP_CREDIT_PERC_VAR                                             0.306549
# ACTIVE_AMT_CREDIT_SUM_MEAN                                               0.293853
# ACTIVE_AMT_CREDIT_SUM_MAX                                                0.293853
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN                                           0.293850
# ACTIVE_CREDIT_DAY_OVERDUE_MAX                                            0.293850
# ACTIVE_DAYS_CREDIT_MIN                                                   0.293850
# ACTIVE_DAYS_CREDIT_MEAN                                                  0.293850
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN                                           0.293850
# ACTIVE_DAYS_CREDIT_MAX                                                   0.293850
# ACTIVE_CNT_CREDIT_PROLONG_SUM                                            0.293850
# ACTIVE_AMT_CREDIT_SUM_SUM                                                0.293850
# ACTIVE_MONTHS_BALANCE_SIZE_SUM                                           0.293850
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN                                       0.293850
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM                                           0.293850
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM                                          0.293850
# CLOSED_AMT_CREDIT_SUM_DEBT_MEAN                                          0.290003
# CLOSED_AMT_CREDIT_SUM_DEBT_MAX                                           0.290003
# BURO_DAYS_CREDIT_VAR                                                     0.260456
# CLOSED_DAYS_CREDIT_ENDDATE_MIN                                           0.256475
# CLOSED_DAYS_CREDIT_ENDDATE_MAX                                           0.256475
# CLOSED_DAYS_CREDIT_ENDDATE_MEAN                                          0.256475
# PREV_APP_CREDIT_PERC_VAR                                                 0.253819
# CLOSED_AMT_CREDIT_SUM_DEBT_SUM                                           0.251526
# CLOSED_AMT_CREDIT_SUM_MAX                                                0.251526
# CLOSED_AMT_CREDIT_SUM_SUM                                                0.251526
# CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN                                       0.251526
# CLOSED_CNT_CREDIT_PROLONG_SUM                                            0.251526
# CLOSED_AMT_CREDIT_SUM_MEAN                                               0.251526
# CLOSED_MONTHS_BALANCE_SIZE_SUM                                           0.251526
# CLOSED_CREDIT_DAY_OVERDUE_MEAN                                           0.251526
# CLOSED_CREDIT_DAY_OVERDUE_MAX                                            0.251526
# CLOSED_DAYS_CREDIT_MEAN                                                  0.251526
# CLOSED_DAYS_CREDIT_MAX                                                   0.251526
# CLOSED_DAYS_CREDIT_MIN                                                   0.251526
# CLOSED_AMT_CREDIT_SUM_LIMIT_SUM                                          0.251526
# CLOSED_DAYS_CREDIT_UPDATE_MEAN                                           0.251526
# BURO_AMT_CREDIT_SUM_LIMIT_MEAN                                           0.211602
# EXT_SOURCE_3                                                             0.198256
# DAYS_EMPLOYED                                                            0.180074
# DAYS_EMPLOYED_PERC                                                       0.180074
# BURO_AMT_CREDIT_SUM_DEBT_MEAN                                            0.167086
# BURO_AMT_CREDIT_SUM_DEBT_MAX                                             0.167086
# BURO_DAYS_CREDIT_ENDDATE_MIN                                             0.150465
# BURO_DAYS_CREDIT_ENDDATE_MAX                                             0.150465
# BURO_DAYS_CREDIT_ENDDATE_MEAN                                            0.150465
# BURO_AMT_CREDIT_SUM_MAX                                                  0.143154
# BURO_AMT_CREDIT_SUM_MEAN                                                 0.143154
# BURO_CNT_CREDIT_PROLONG_SUM                                              0.143151
# BURO_AMT_CREDIT_SUM_LIMIT_SUM                                            0.143151
# BURO_AMT_CREDIT_SUM_OVERDUE_MEAN                                         0.143151
# BURO_AMT_CREDIT_SUM_DEBT_SUM                                             0.143151
# BURO_AMT_CREDIT_SUM_SUM                                                  0.143151
# BURO_CREDIT_DAY_OVERDUE_MAX                                              0.143151
# BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN       0.143151
# BURO_CREDIT_DAY_OVERDUE_MEAN                                             0.143151
# BURO_CREDIT_ACTIVE_Active_MEAN                                           0.143151
# BURO_DAYS_CREDIT_UPDATE_MEAN                                             0.143151
# BURO_DAYS_CREDIT_MEAN                                                    0.143151
# BURO_DAYS_CREDIT_MAX                                                     0.143151
# BURO_DAYS_CREDIT_MIN                                                     0.143151
# BURO_MONTHS_BALANCE_SIZE_SUM                                             0.143151
# BURO_CREDIT_TYPE_Loan for business development_MEAN                      0.143151
# BURO_CREDIT_ACTIVE_Bad debt_MEAN                                         0.143151
# BURO_CREDIT_TYPE_Credit card_MEAN                                        0.143151
# BURO_CREDIT_ACTIVE_Closed_MEAN                                           0.143151
# BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN                 0.143151
# BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN             0.143151
# BURO_CREDIT_TYPE_Microloan_MEAN                                          0.143151
# BURO_CREDIT_TYPE_Mobile operator loan_MEAN                               0.143151
# BURO_CREDIT_TYPE_Mortgage_MEAN                                           0.143151
# BURO_CREDIT_TYPE_Real estate loan_MEAN                                   0.143151
# BURO_CREDIT_TYPE_Unknown type of loan_MEAN                               0.143151
# BURO_CREDIT_TYPE_nan_MEAN                                                0.143151
# BURO_CREDIT_TYPE_Interbank credit_MEAN                                   0.143151
# BURO_CREDIT_CURRENCY_currency 4_MEAN                                     0.143151
# BURO_CREDIT_TYPE_Consumer credit_MEAN                                    0.143151
# BURO_CREDIT_TYPE_Car loan_MEAN                                           0.143151
# BURO_CREDIT_TYPE_Another type of loan_MEAN                               0.143151
# BURO_CREDIT_CURRENCY_nan_MEAN                                            0.143151
# BURO_CREDIT_CURRENCY_currency 3_MEAN                                     0.143151
# BURO_CREDIT_CURRENCY_currency 2_MEAN                                     0.143151
# BURO_CREDIT_CURRENCY_currency 1_MEAN                                     0.143151
# BURO_CREDIT_ACTIVE_nan_MEAN                                              0.143151
# BURO_CREDIT_ACTIVE_Sold_MEAN                                             0.143151
# BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN                          0.143151
# AMT_REQ_CREDIT_BUREAU_QRT                                                0.135018
# AMT_REQ_CREDIT_BUREAU_YEAR                                               0.135018
# AMT_REQ_CREDIT_BUREAU_HOUR                                               0.135018
# AMT_REQ_CREDIT_BUREAU_MON                                                0.135018
# AMT_REQ_CREDIT_BUREAU_DAY                                                0.135018
# AMT_REQ_CREDIT_BUREAU_WEEK                                               0.135018
# APPROVED_RATE_DOWN_PAYMENT_MIN                                           0.117792
# APPROVED_AMT_DOWN_PAYMENT_MIN                                            0.117792
# APPROVED_AMT_DOWN_PAYMENT_MAX                                            0.117792
# APPROVED_AMT_DOWN_PAYMENT_MEAN                                           0.117792
# APPROVED_RATE_DOWN_PAYMENT_MEAN                                          0.117792
# APPROVED_RATE_DOWN_PAYMENT_MAX                                           0.117792
# PREV_RATE_DOWN_PAYMENT_MIN                                               0.110261
# PREV_AMT_DOWN_PAYMENT_MEAN                                               0.110261
# PREV_RATE_DOWN_PAYMENT_MEAN                                              0.110261
# PREV_AMT_DOWN_PAYMENT_MAX                                                0.110261
# PREV_AMT_DOWN_PAYMENT_MIN                                                0.110261
# PREV_RATE_DOWN_PAYMENT_MAX                                               0.110261
# APPROVED_AMT_GOODS_PRICE_MEAN                                            0.059917
# APPROVED_AMT_GOODS_PRICE_MAX                                             0.059917
# APPROVED_AMT_GOODS_PRICE_MIN                                             0.059917
# POS_NAME_CONTRACT_STATUS_Active_MEAN                                     0.058753
# POS_SK_DPD_DEF_MEAN                                                      0.058753
# POS_SK_DPD_DEF_MAX                                                       0.058753
# POS_NAME_CONTRACT_STATUS_Canceled_MEAN                                   0.058753
# POS_NAME_CONTRACT_STATUS_Completed_MEAN                                  0.058753
# POS_MONTHS_BALANCE_MAX                                                   0.058753
# POS_MONTHS_BALANCE_MEAN                                                  0.058753
# POS_NAME_CONTRACT_STATUS_Demand_MEAN                                     0.058753
# POS_MONTHS_BALANCE_SIZE                                                  0.058753
# POS_SK_DPD_MAX                                                           0.058753
# POS_SK_DPD_MEAN                                                          0.058753
# POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN                      0.058753
# POS_NAME_CONTRACT_STATUS_Signed_MEAN                                     0.058753
# POS_NAME_CONTRACT_STATUS_XNA_MEAN                                        0.058753
# POS_NAME_CONTRACT_STATUS_nan_MEAN                                        0.058753
# POS_NAME_CONTRACT_STATUS_Approved_MEAN                                   0.058753
# POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN                             0.058753
# POS_COUNT                                                                0.058753
# APPROVED_APP_CREDIT_PERC_MAX                                             0.056763
# APPROVED_APP_CREDIT_PERC_MIN                                             0.056763
# APPROVED_APP_CREDIT_PERC_MEAN                                            0.056763
# APPROVED_AMT_ANNUITY_MEAN                                                0.056740
# APPROVED_AMT_ANNUITY_MAX                                                 0.056740
# APPROVED_AMT_ANNUITY_MIN                                                 0.056740
# APPROVED_AMT_CREDIT_MEAN                                                 0.056734
# APPROVED_AMT_CREDIT_MIN                                                  0.056734
# APPROVED_AMT_APPLICATION_MEAN                                            0.056734
# APPROVED_AMT_APPLICATION_MAX                                             0.056734
# APPROVED_AMT_APPLICATION_MIN                                             0.056734
# APPROVED_CNT_PAYMENT_SUM                                                 0.056734
# APPROVED_AMT_CREDIT_MAX                                                  0.056734
# APPROVED_HOUR_APPR_PROCESS_START_MIN                                     0.056734
# APPROVED_DAYS_DECISION_MAX                                               0.056734
# APPROVED_HOUR_APPR_PROCESS_START_MAX                                     0.056734
# APPROVED_HOUR_APPR_PROCESS_START_MEAN                                    0.056734
# APPROVED_CNT_PAYMENT_MEAN                                                0.056734
# APPROVED_DAYS_DECISION_MEAN                                              0.056734
# APPROVED_DAYS_DECISION_MIN                                               0.056734
# PREV_AMT_GOODS_PRICE_MEAN                                                0.056678
# PREV_AMT_GOODS_PRICE_MAX                                                 0.056678
# PREV_AMT_GOODS_PRICE_MIN                                                 0.056678
# PREV_AMT_ANNUITY_MAX                                                     0.054864
# PREV_AMT_ANNUITY_MEAN                                                    0.054864
# PREV_AMT_ANNUITY_MIN                                                     0.054864
# PREV_CNT_PAYMENT_MEAN                                                    0.054857
# PREV_APP_CREDIT_PERC_MEAN                                                0.054249
# PREV_APP_CREDIT_PERC_MIN                                                 0.054246
# PREV_APP_CREDIT_PERC_MAX                                                 0.054246
# INSTAL_PAYMENT_PERC_VAR                                                  0.053924
# INSTAL_PAYMENT_DIFF_VAR                                                  0.053865
# PREV_CHANNEL_TYPE_Stone_MEAN                                             0.053508
# PREV_NAME_PORTFOLIO_POS_MEAN                                             0.053508
# PREV_NAME_PORTFOLIO_XNA_MEAN                                             0.053508
# PREV_NAME_PORTFOLIO_nan_MEAN                                             0.053508
# PREV_NAME_PRODUCT_TYPE_XNA_MEAN                                          0.053508
# PREV_NAME_PRODUCT_TYPE_walk-in_MEAN                                      0.053508
# PREV_NAME_PRODUCT_TYPE_x-sell_MEAN                                       0.053508
# PREV_NAME_PRODUCT_TYPE_nan_MEAN                                          0.053508
# PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN                        0.053508
# PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN                                   0.053508
# PREV_CHANNEL_TYPE_Car dealer_MEAN                                        0.053508
# PREV_CHANNEL_TYPE_Contact center_MEAN                                    0.053508
# PREV_CHANNEL_TYPE_Country-wide_MEAN                                      0.053508
# PREV_CHANNEL_TYPE_Credit and cash offices_MEAN                           0.053508
# PREV_CHANNEL_TYPE_Regional / Local_MEAN                                  0.053508
# PREV_NAME_PORTFOLIO_Cars_MEAN                                            0.053508
# PREV_NAME_PORTFOLIO_Cash_MEAN                                            0.053508
# PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN                   0.053508
# PREV_NAME_PORTFOLIO_Cards_MEAN                                           0.053508
# PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN                          0.053508
# PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN                           0.053508
# PREV_NAME_GOODS_CATEGORY_Insurance_MEAN                                  0.053508
# PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN                                    0.053508
# PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN                           0.053508
# PREV_NAME_GOODS_CATEGORY_Medicine_MEAN                                   0.053508
# PREV_NAME_GOODS_CATEGORY_Mobile_MEAN                                     0.053508
# PREV_NAME_GOODS_CATEGORY_Other_MEAN                                      0.053508
# PREV_NAME_GOODS_CATEGORY_nan_MEAN                                        0.053508
# PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN                          0.053508
# PREV_NAME_GOODS_CATEGORY_Tourism_MEAN                                    0.053508
# PREV_NAME_GOODS_CATEGORY_House Construction_MEAN                         0.053508
# PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN                                   0.053508
# PREV_NAME_GOODS_CATEGORY_Weapon_MEAN                                     0.053508
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN                                        0.053508
# PREV_CHANNEL_TYPE_nan_MEAN                                               0.053508
# PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN                           0.053508
# PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN                                  0.053508
# PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN                              0.053508
# PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN                          0.053508
# PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN                           0.053508
# PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN                        0.053508
# PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN                          0.053508
# PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN                        0.053508
# PREV_PRODUCT_COMBINATION_POS household with interest_MEAN                0.053508
# PREV_PRODUCT_COMBINATION_POS household without interest_MEAN             0.053508
# PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN                 0.053508
# PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN              0.053508
# PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN                   0.053508
# PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN                0.053508
# PREV_PRODUCT_COMBINATION_POS other with interest_MEAN                    0.053508
# PREV_PRODUCT_COMBINATION_POS others without interest_MEAN                0.053508
# PREV_PRODUCT_COMBINATION_nan_MEAN                                        0.053508
# PREV_NAME_GOODS_CATEGORY_Gardening_MEAN                                  0.053508
# PREV_PRODUCT_COMBINATION_Cash_MEAN                                       0.053508
# PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN                                0.053508
# PREV_PRODUCT_COMBINATION_Card Street_MEAN                                0.053508
# PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN                                   0.053508
# PREV_NAME_SELLER_INDUSTRY_Construction_MEAN                              0.053508
# PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN                      0.053508
# PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN                                 0.053508
# PREV_NAME_SELLER_INDUSTRY_Industry_MEAN                                  0.053508
# PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN                                   0.053508
# PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN                              0.053508
# PREV_NAME_SELLER_INDUSTRY_XNA_MEAN                                       0.053508
# PREV_NAME_YIELD_GROUP_nan_MEAN                                           0.053508
# PREV_NAME_SELLER_INDUSTRY_nan_MEAN                                       0.053508
# PREV_NAME_YIELD_GROUP_XNA_MEAN                                           0.053508
# PREV_NAME_YIELD_GROUP_high_MEAN                                          0.053508
# PREV_NAME_YIELD_GROUP_low_action_MEAN                                    0.053508
# PREV_NAME_YIELD_GROUP_low_normal_MEAN                                    0.053508
# PREV_NAME_YIELD_GROUP_middle_MEAN                                        0.053508
# PREV_NAME_GOODS_CATEGORY_Homewares_MEAN                                  0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN                              0.053508
# PREV_NAME_GOODS_CATEGORY_Furniture_MEAN                                  0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN                           0.053508
# PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN                                  0.053508
# PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN                                  0.053508
# PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN                                0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN            0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN                    0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN                         0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN            0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN                           0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN                        0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN                       0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN                             0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN                               0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN                       0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN                               0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN             0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN                                   0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN                                 0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN                                0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN                0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN                                   0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN                 0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN                                 0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN                             0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN                0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN                            0.053508
# PREV_AMT_APPLICATION_MAX                                                 0.053508
# PREV_AMT_APPLICATION_MEAN                                                0.053508
# PREV_AMT_CREDIT_MIN                                                      0.053508
# PREV_AMT_CREDIT_MAX                                                      0.053508
# PREV_AMT_CREDIT_MEAN                                                     0.053508
# PREV_HOUR_APPR_PROCESS_START_MIN                                         0.053508
# PREV_HOUR_APPR_PROCESS_START_MAX                                         0.053508
# PREV_HOUR_APPR_PROCESS_START_MEAN                                        0.053508
# PREV_DAYS_DECISION_MIN                                                   0.053508
# PREV_DAYS_DECISION_MAX                                                   0.053508
# PREV_DAYS_DECISION_MEAN                                                  0.053508
# PREV_CNT_PAYMENT_SUM                                                     0.053508
# PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN                                  0.053508
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN                              0.053508
# PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN                             0.053508
# PREV_NAME_CONTRACT_TYPE_XNA_MEAN                                         0.053508
# PREV_NAME_CONTRACT_TYPE_nan_MEAN                                         0.053508
# PREV_NAME_GOODS_CATEGORY_Fitness_MEAN                                    0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN                              0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN                            0.053508
# PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN                              0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN        0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN                                 0.053508
# PREV_CODE_REJECT_REASON_nan_MEAN                                         0.053508
# PREV_NAME_CLIENT_TYPE_XNA_MEAN                                           0.053508
# PREV_NAME_TYPE_SUITE_Family_MEAN                                         0.053508
# PREV_NAME_TYPE_SUITE_Group of people_MEAN                                0.053508
# PREV_NAME_TYPE_SUITE_Other_A_MEAN                                        0.053508
# PREV_NAME_TYPE_SUITE_Other_B_MEAN                                        0.053508
# PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN                                0.053508
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN                                  0.053508
# PREV_NAME_TYPE_SUITE_nan_MEAN                                            0.053508
# PREV_NAME_CLIENT_TYPE_New_MEAN                                           0.053508
# PREV_NAME_CLIENT_TYPE_Refreshed_MEAN                                     0.053508
# PREV_NAME_CLIENT_TYPE_Repeater_MEAN                                      0.053508
# PREV_NAME_CLIENT_TYPE_nan_MEAN                                           0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN                            0.053508
# PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN                         0.053508
# PREV_NAME_GOODS_CATEGORY_Animals_MEAN                                    0.053508
# PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN                                0.053508
# PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN                           0.053508
# PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN                   0.053508
# PREV_NAME_GOODS_CATEGORY_Computers_MEAN                                  0.053508
# PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN                     0.053508
# PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN                       0.053508
# PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN                               0.053508
# PREV_NAME_GOODS_CATEGORY_Education_MEAN                                  0.053508
# PREV_NAME_TYPE_SUITE_Children_MEAN                                       0.053508
# PREV_AMT_APPLICATION_MIN                                                 0.053508
# PREV_CODE_REJECT_REASON_XNA_MEAN                                         0.053508
# PREV_CODE_REJECT_REASON_XAP_MEAN                                         0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN                0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN                                     0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN                                     0.053508
# PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN                                     0.053508
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN                                  0.053508
# PREV_NAME_CONTRACT_STATUS_Canceled_MEAN                                  0.053508
# PREV_NAME_CONTRACT_STATUS_Refused_MEAN                                   0.053508
# PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN                              0.053508
# PREV_NAME_CONTRACT_STATUS_nan_MEAN                                       0.053508
# PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN                        0.053508
# PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN    0.053508
# PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN                   0.053508
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN                                          0.053508
# PREV_NAME_PAYMENT_TYPE_nan_MEAN                                          0.053508
# PREV_CODE_REJECT_REASON_CLIENT_MEAN                                      0.053508
# PREV_CODE_REJECT_REASON_HC_MEAN                                          0.053508
# PREV_CODE_REJECT_REASON_LIMIT_MEAN                                       0.053508
# PREV_CODE_REJECT_REASON_SCO_MEAN                                         0.053508
# PREV_CODE_REJECT_REASON_SCOFR_MEAN                                       0.053508
# PREV_CODE_REJECT_REASON_SYSTEM_MEAN                                      0.053508
# PREV_CODE_REJECT_REASON_VERIF_MEAN                                       0.053508
# INSTAL_PAYMENT_PERC_MEAN                                                 0.051687
# INSTAL_PAYMENT_PERC_SUM                                                  0.051661
# INSTAL_PAYMENT_DIFF_MAX                                                  0.051628
# INSTAL_PAYMENT_DIFF_MEAN                                                 0.051628
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN                                           0.051628
# ...
# INSTAL_COUNT                                                             0.051602
# DEF_60_CNT_SOCIAL_CIRCLE                                                 0.003320
# OBS_60_CNT_SOCIAL_CIRCLE                                                 0.003320
# DEF_30_CNT_SOCIAL_CIRCLE                                                 0.003320
# OBS_30_CNT_SOCIAL_CIRCLE                                                 0.003320
# EXT_SOURCE_2                                                             0.002146
# AMT_GOODS_PRICE                                                          0.000904
# PAYMENT_RATE                                                             0.000039
# ANNUITY_INCOME_PERC                                                      0.000039
# AMT_ANNUITY                                                              0.000039
# INCOME_PER_PERSON                                                        0.000007
# CNT_FAM_MEMBERS                                                          0.000007
# DAYS_LAST_PHONE_CHANGE                                                   0.000003
# LIVE_CITY_NOT_WORK_CITY                                                  0.000000
# NAME_INCOME_TYPE_Unemployed                                              0.000000
# NAME_INCOME_TYPE_Student                                                 0.000000
# NAME_INCOME_TYPE_State servant                                           0.000000
# NAME_INCOME_TYPE_Pensioner                                               0.000000
# NAME_INCOME_TYPE_Maternity leave                                         0.000000
# NAME_INCOME_TYPE_Commercial associate                                    0.000000
# NAME_INCOME_TYPE_Businessman                                             0.000000
# NAME_TYPE_SUITE_Unaccompanied                                            0.000000
# NAME_TYPE_SUITE_Spouse, partner                                          0.000000
# NAME_EDUCATION_TYPE_Academic degree                                      0.000000
# NAME_TYPE_SUITE_Other_B                                                  0.000000
# NAME_TYPE_SUITE_Other_A                                                  0.000000
# NAME_TYPE_SUITE_Group of people                                          0.000000
# NAME_TYPE_SUITE_Family                                                   0.000000
# NAME_TYPE_SUITE_Children                                                 0.000000
# NAME_CONTRACT_TYPE_Revolving loans                                       0.000000
# NAME_CONTRACT_TYPE_Cash loans                                            0.000000
# FLAG_DOCUMENT_21                                                         0.000000
# NAME_INCOME_TYPE_Working                                                 0.000000
# NAME_EDUCATION_TYPE_Incomplete higher                                    0.000000
# NAME_EDUCATION_TYPE_Higher education                                     0.000000
# NAME_HOUSING_TYPE_House / apartment                                      0.000000
# OCCUPATION_TYPE_Core staff                                               0.000000
# OCCUPATION_TYPE_Cooking staff                                            0.000000
# OCCUPATION_TYPE_Cleaning staff                                           0.000000
# OCCUPATION_TYPE_Accountants                                              0.000000
# NAME_HOUSING_TYPE_With parents                                           0.000000
# NAME_HOUSING_TYPE_Rented apartment                                       0.000000
# NAME_HOUSING_TYPE_Office apartment                                       0.000000
# NAME_HOUSING_TYPE_Municipal apartment                                    0.000000
# NAME_HOUSING_TYPE_Co-op apartment                                        0.000000
# FLAG_DOCUMENT_19                                                         0.000000
# NAME_FAMILY_STATUS_Widow                                                 0.000000
# NAME_FAMILY_STATUS_Unknown                                               0.000000
# NAME_FAMILY_STATUS_Single / not married                                  0.000000
# NAME_FAMILY_STATUS_Separated                                             0.000000
# NAME_FAMILY_STATUS_Married                                               0.000000
# NAME_FAMILY_STATUS_Civil marriage                                        0.000000
# NAME_EDUCATION_TYPE_Secondary / secondary special                        0.000000
# NAME_EDUCATION_TYPE_Lower secondary                                      0.000000
# FLAG_DOCUMENT_20                                                         0.000000
# FLAG_DOCUMENT_17                                                         0.000000
# FLAG_DOCUMENT_18                                                         0.000000
# FLAG_DOCUMENT_8                                                          0.000000
# REGION_RATING_CLIENT_W_CITY                                              0.000000
# HOUR_APPR_PROCESS_START                                                  0.000000
# REG_REGION_NOT_LIVE_REGION                                               0.000000
# FLAG_DOCUMENT_13                                                         0.000000
# FLAG_DOCUMENT_12                                                         0.000000
# FLAG_DOCUMENT_11                                                         0.000000
# FLAG_DOCUMENT_10                                                         0.000000
# FLAG_DOCUMENT_9                                                          0.000000
# FLAG_DOCUMENT_7                                                          0.000000
# REG_CITY_NOT_WORK_CITY                                                   0.000000
# FLAG_DOCUMENT_6                                                          0.000000
# FLAG_DOCUMENT_5                                                          0.000000
# FLAG_DOCUMENT_4                                                          0.000000
# FLAG_DOCUMENT_3                                                          0.000000
# FLAG_DOCUMENT_2                                                          0.000000
# REG_REGION_NOT_WORK_REGION                                               0.000000
# LIVE_REGION_NOT_WORK_REGION                                              0.000000
# REG_CITY_NOT_LIVE_CITY                                                   0.000000
# REGION_RATING_CLIENT                                                     0.000000
# FLAG_EMAIL                                                               0.000000
# FLAG_PHONE                                                               0.000000
# FLAG_CONT_MOBILE                                                         0.000000
# CODE_GENDER                                                              0.000000
# FLAG_OWN_CAR                                                             0.000000
# FLAG_OWN_REALTY                                                          0.000000
# CNT_CHILDREN                                                             0.000000
# AMT_INCOME_TOTAL                                                         0.000000
# AMT_CREDIT                                                               0.000000
# REGION_POPULATION_RELATIVE                                               0.000000
# DAYS_BIRTH                                                               0.000000
# DAYS_REGISTRATION                                                        0.000000
# DAYS_ID_PUBLISH                                                          0.000000
# FLAG_DOCUMENT_16                                                         0.000000
# FLAG_MOBIL                                                               0.000000
# FLAG_EMP_PHONE                                                           0.000000
# OCCUPATION_TYPE_HR staff                                                 0.000000
# FLAG_DOCUMENT_15                                                         0.000000
# FLAG_DOCUMENT_14                                                         0.000000
# FLAG_WORK_PHONE                                                          0.000000
# OCCUPATION_TYPE_Drivers                                                  0.000000
# WEEKDAY_APPR_PROCESS_START_FRIDAY                                        0.000000
# OCCUPATION_TYPE_High skill tech staff                                    0.000000
# ORGANIZATION_TYPE_Security Ministries                                    0.000000
# ORGANIZATION_TYPE_Trade: type 6                                          0.000000
# ORGANIZATION_TYPE_Trade: type 5                                          0.000000
# ORGANIZATION_TYPE_Trade: type 4                                          0.000000
# ORGANIZATION_TYPE_Trade: type 3                                          0.000000
# ORGANIZATION_TYPE_Trade: type 2                                          0.000000
# ORGANIZATION_TYPE_Trade: type 1                                          0.000000
# ORGANIZATION_TYPE_Telecom                                                0.000000
# ORGANIZATION_TYPE_Services                                               0.000000
# ORGANIZATION_TYPE_Self-employed                                          0.000000
# ORGANIZATION_TYPE_Security                                               0.000000
# ORGANIZATION_TYPE_Transport: type 1                                      0.000000
# ORGANIZATION_TYPE_School                                                 0.000000
# ORGANIZATION_TYPE_Restaurant                                             0.000000
# ORGANIZATION_TYPE_Religion                                               0.000000
# ORGANIZATION_TYPE_Realtor                                                0.000000
# ORGANIZATION_TYPE_Postal                                                 0.000000
# ORGANIZATION_TYPE_Police                                                 0.000000
# ORGANIZATION_TYPE_Other                                                  0.000000
# ORGANIZATION_TYPE_Mobile                                                 0.000000
# ORGANIZATION_TYPE_Military                                               0.000000
# ORGANIZATION_TYPE_Trade: type 7                                          0.000000
# ORGANIZATION_TYPE_Transport: type 2                                      0.000000
# ORGANIZATION_TYPE_Legal Services                                         0.000000
# WALLSMATERIAL_MODE_Block                                                 0.000000
# INCOME_CREDIT_PERC                                                       0.000000
# EMERGENCYSTATE_MODE_Yes                                                  0.000000
# EMERGENCYSTATE_MODE_No                                                   0.000000
# WALLSMATERIAL_MODE_Wooden                                                0.000000
# WALLSMATERIAL_MODE_Stone, brick                                          0.000000
# WALLSMATERIAL_MODE_Panel                                                 0.000000
# WALLSMATERIAL_MODE_Others                                                0.000000
# WALLSMATERIAL_MODE_Monolithic                                            0.000000
# WALLSMATERIAL_MODE_Mixed                                                 0.000000
# HOUSETYPE_MODE_terraced house                                            0.000000
# ORGANIZATION_TYPE_Transport: type 3                                      0.000000
# HOUSETYPE_MODE_specific housing                                          0.000000
# HOUSETYPE_MODE_block of flats                                            0.000000
# FONDKAPREMONT_MODE_reg oper spec account                                 0.000000
# FONDKAPREMONT_MODE_reg oper account                                      0.000000
# FONDKAPREMONT_MODE_org spec account                                      0.000000
# FONDKAPREMONT_MODE_not specified                                         0.000000
# ORGANIZATION_TYPE_XNA                                                    0.000000
# ORGANIZATION_TYPE_University                                             0.000000
# ORGANIZATION_TYPE_Transport: type 4                                      0.000000
# ORGANIZATION_TYPE_Medicine                                               0.000000
# TARGET                                                                   0.000000
# OCCUPATION_TYPE_IT staff                                                 0.000000
# WEEKDAY_APPR_PROCESS_START_MONDAY                                        0.000000
# ORGANIZATION_TYPE_Business Entity Type 1                                 0.000000
# ORGANIZATION_TYPE_Bank                                                   0.000000
# ORGANIZATION_TYPE_Agriculture                                            0.000000
# ORGANIZATION_TYPE_Advertising                                            0.000000
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY                                     0.000000
# WEEKDAY_APPR_PROCESS_START_TUESDAY                                       0.000000
# WEEKDAY_APPR_PROCESS_START_THURSDAY                                      0.000000
# WEEKDAY_APPR_PROCESS_START_SUNDAY                                        0.000000
# WEEKDAY_APPR_PROCESS_START_SATURDAY                                      0.000000
# OCCUPATION_TYPE_Waiters/barmen staff                                     0.000000
# ORGANIZATION_TYPE_Business Entity Type 3                                 0.000000
# OCCUPATION_TYPE_Security staff                                           0.000000
# OCCUPATION_TYPE_Secretaries                                              0.000000
# OCCUPATION_TYPE_Sales staff                                              0.000000
# OCCUPATION_TYPE_Realty agents                                            0.000000
# OCCUPATION_TYPE_Private service staff                                    0.000000
# OCCUPATION_TYPE_Medicine staff                                           0.000000
# OCCUPATION_TYPE_Managers                                                 0.000000
# OCCUPATION_TYPE_Low-skill Laborers                                       0.000000
# OCCUPATION_TYPE_Laborers                                                 0.000000
# ORGANIZATION_TYPE_Business Entity Type 2                                 0.000000
# ORGANIZATION_TYPE_Cleaning                                               0.000000
# ORGANIZATION_TYPE_Kindergarten                                           0.000000
# ORGANIZATION_TYPE_Industry: type 13                                      0.000000
# ORGANIZATION_TYPE_Insurance                                              0.000000
# ORGANIZATION_TYPE_Industry: type 9                                       0.000000
# ORGANIZATION_TYPE_Industry: type 8                                       0.000000
# ORGANIZATION_TYPE_Industry: type 7                                       0.000000
# ORGANIZATION_TYPE_Industry: type 6                                       0.000000
# ORGANIZATION_TYPE_Industry: type 5                                       0.000000
# ORGANIZATION_TYPE_Industry: type 4                                       0.000000
# ORGANIZATION_TYPE_Industry: type 3                                       0.000000
# ORGANIZATION_TYPE_Industry: type 2                                       0.000000
# ORGANIZATION_TYPE_Industry: type 12                                      0.000000
# ORGANIZATION_TYPE_Construction                                           0.000000
# ORGANIZATION_TYPE_Industry: type 11                                      0.000000
# ORGANIZATION_TYPE_Industry: type 10                                      0.000000
# ORGANIZATION_TYPE_Industry: type 1                                       0.000000
# ORGANIZATION_TYPE_Housing                                                0.000000
# ORGANIZATION_TYPE_Hotel                                                  0.000000
# ORGANIZATION_TYPE_Government                                             0.000000
# ORGANIZATION_TYPE_Emergency                                              0.000000
# ORGANIZATION_TYPE_Electricity                                            0.000000
# ORGANIZATION_TYPE_Culture                                                0.000000
# SK_ID_CURR                                                               0.000000
# dtype: float64

# %% [markdown]
# ### Variables Qualitatives
# Il subsiste des valeurs de type *object*. Que contiennent-elles ?

# %%
for col in df.select_dtypes('object'):
    print(f'{col :-<50} {df[col].unique()}')
# Out:
# CC_NAME_CONTRACT_STATUS_Active_MIN---------------- [nan True False]
# CC_NAME_CONTRACT_STATUS_Active_MAX---------------- [nan True False]
# CC_NAME_CONTRACT_STATUS_Approved_MIN-------------- [nan False]
# CC_NAME_CONTRACT_STATUS_Approved_MAX-------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Completed_MIN------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Completed_MAX------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Demand_MIN---------------- [nan False]
# CC_NAME_CONTRACT_STATUS_Demand_MAX---------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Refused_MIN--------------- [nan False]
# CC_NAME_CONTRACT_STATUS_Refused_MAX--------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN--------- [nan False]
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX--------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Signed_MIN---------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_Signed_MAX---------------- [nan False True]
# CC_NAME_CONTRACT_STATUS_nan_MIN------------------- [nan False]
# CC_NAME_CONTRACT_STATUS_nan_MAX------------------- [nan False]

# %%
# Valeurs dupliquées
df.duplicated().sum()
# Out:
# 0

# %%
# Valeurs dupliquées sur colonnes hors Target
df.drop(columns='TARGET').duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           SK_ID_CURR        TARGET    CODE_GENDER   FLAG_OWN_CAR  \
# count  307507.000000  307507.00000  307507.000000  307507.000000
# mean   278181.527256       0.08073       0.658352       0.340106
# std    102790.132982       0.27242       0.474263       0.473745
# min    100002.000000       0.00000       0.000000       0.000000
# 25%    189146.500000       0.00000       0.000000       0.000000
# 50%    278203.000000       0.00000       1.000000       0.000000
# 75%    367143.500000       0.00000       1.000000       1.000000
# max    456255.000000       1.00000       1.000000       1.000000
#
#        FLAG_OWN_REALTY   CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT  \
# count    307507.000000  307507.000000      3.075070e+05  3.075070e+05
# mean          0.306331       0.417047      1.687977e+05  5.990286e+05
# std           0.460970       0.722119      2.371246e+05  4.024926e+05
# min           0.000000       0.000000      2.565000e+04  4.500000e+04
# 25%           0.000000       0.000000      1.125000e+05  2.700000e+05
# 50%           0.000000       0.000000      1.471500e+05  5.135310e+05
# 75%           1.000000       1.000000      2.025000e+05  8.086500e+05
# max           1.000000      19.000000      1.170000e+08  4.050000e+06
#
#          AMT_ANNUITY  AMT_GOODS_PRICE  ...  \
# count  307495.000000     3.072290e+05  ...
# mean    27108.666786     5.383977e+05  ...
# std     14493.798379     3.694472e+05  ...
# min      1615.500000     4.050000e+04  ...
# 25%     16524.000000     2.385000e+05  ...
# 50%     24903.000000     4.500000e+05  ...
# 75%     34596.000000     6.795000e+05  ...
# max    258025.500000     4.050000e+06  ...
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN  \
# count                                86905.000000
# mean                                     0.000064
# std                                      0.000877
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      0.024390
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_SUM  \
# count                               86905.000000
# mean                                    0.005293
# std                                     0.072562
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        CC_NAME_CONTRACT_STATUS_Sent proposal_VAR  \
# count                               86273.000000
# mean                                    0.000064
# std                                     0.000881
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     0.024390
#
#        CC_NAME_CONTRACT_STATUS_Signed_MEAN  \
# count                         86905.000000
# mean                              0.003738
# std                               0.031882
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        CC_NAME_CONTRACT_STATUS_Signed_SUM  CC_NAME_CONTRACT_STATUS_Signed_VAR  \
# count                        86905.000000                         86273.00000
# mean                             0.114366                             0.00307
# std                              1.323208                             0.02036
# min                              0.000000                             0.00000
# 25%                              0.000000                             0.00000
# 50%                              0.000000                             0.00000
# 75%                              0.000000                             0.00000
# max                             62.000000                             0.50000
#
#        CC_NAME_CONTRACT_STATUS_nan_MEAN  CC_NAME_CONTRACT_STATUS_nan_SUM  \
# count                           86905.0                          86905.0
# mean                                0.0                              0.0
# std                                 0.0                              0.0
# min                                 0.0                              0.0
# 25%                                 0.0                              0.0
# 50%                                 0.0                              0.0
# 75%                                 0.0                              0.0
# max                                 0.0                              0.0
#
#        CC_NAME_CONTRACT_STATUS_nan_VAR      CC_COUNT
# count                          86273.0  86905.000000
# mean                               0.0     37.143605
# std                                0.0     33.698512
# min                                0.0      1.000000
# 25%                                0.0     10.000000
# 50%                                0.0     22.000000
# 75%                                0.0     75.000000
# max                                0.0    192.000000
#
# [8 rows x 648 columns]

# %%
df['TARGET'].value_counts(normalize=True).plot(kind='pie', autopct='%.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
# Colonnes potentiellement inutiles, faute de variation des valeurs
tmp = df.nunique()
tmp[tmp==1]
# Out:
# BURO_CREDIT_ACTIVE_nan_MEAN                         1
# BURO_CREDIT_CURRENCY_nan_MEAN                       1
# BURO_CREDIT_TYPE_nan_MEAN                           1
# BURO_STATUS_nan_MEAN_MEAN                           1
# PREV_NAME_CONTRACT_TYPE_nan_MEAN                    1
# PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN            1
# PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN           1
# PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN                1
# PREV_NAME_CONTRACT_STATUS_nan_MEAN                  1
# PREV_NAME_PAYMENT_TYPE_nan_MEAN                     1
# PREV_CODE_REJECT_REASON_nan_MEAN                    1
# PREV_NAME_CLIENT_TYPE_nan_MEAN                      1
# PREV_NAME_GOODS_CATEGORY_House Construction_MEAN    1
# PREV_NAME_GOODS_CATEGORY_nan_MEAN                   1
# PREV_NAME_PORTFOLIO_nan_MEAN                        1
# PREV_NAME_PRODUCT_TYPE_nan_MEAN                     1
# PREV_CHANNEL_TYPE_nan_MEAN                          1
# PREV_NAME_SELLER_INDUSTRY_nan_MEAN                  1
# PREV_NAME_YIELD_GROUP_nan_MEAN                      1
# POS_NAME_CONTRACT_STATUS_nan_MEAN                   1
# CC_SK_DPD_MIN                                       1
# CC_SK_DPD_DEF_MIN                                   1
# CC_NAME_CONTRACT_STATUS_Approved_MIN                1
# CC_NAME_CONTRACT_STATUS_Demand_MIN                  1
# CC_NAME_CONTRACT_STATUS_Refused_MIN                 1
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN           1
# CC_NAME_CONTRACT_STATUS_nan_MIN                     1
# CC_NAME_CONTRACT_STATUS_nan_MAX                     1
# CC_NAME_CONTRACT_STATUS_nan_MEAN                    1
# CC_NAME_CONTRACT_STATUS_nan_SUM                     1
# CC_NAME_CONTRACT_STATUS_nan_VAR                     1
# dtype: int64

# %% [markdown]
# ## Préparation des données

# %% [markdown]
# ### Test train split

# %%
trainset , testset = train_test_split(df, test_size=0.3, random_state=39)

# %%
trainset.TARGET.value_counts(normalize=True).plot(kind='pie', autopct='%.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# Le *trainset* conserve les mêmes proportions de target.

# %%
testset.TARGET.value_counts(normalize=True).plot(kind='pie', autopct='%.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# Le *testset* a une proportion légèrement moindre d'échantillons positifs.

# %% [markdown]
# ### Préprocessing

# %%
def suppression_colonnes_nan(df, taux_nan):
    df = df[df.columns[df.isna().mean() < taux_nan]]
        
    return df

# %%
def suppression_identifiant(df):
    return df.drop(columns={'SK_ID_CURR'})

# %%
def preprocessing(df, taux_nan=0.8):
    
    df = suppression_colonnes_nan(df, taux_nan)
    df = suppression_identifiant(df)
    
    X = df.drop(columns={'TARGET'})
    y = df['TARGET']
    
    print(y.value_counts())
    
    return X, y

# %%
X_train, y_train = preprocessing(trainset, taux_nan=0.8)
# Out:
# TARGET
# 0.0    197758
# 1.0     17496
# Name: count, dtype: int64

# %% [markdown]
# ## Modélisation
# ### Dummy classifier

# %%
model = DecisionTreeClassifier(random_state=39)

# %%
def evaluation(model):
    
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test, ypred))

# %%
evaluation(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 evaluation(model)
#
# Cell In[34], line 3, in evaluation(model)
#       1 def evaluation(model):
# ----> 3     model.fit(X_train, y_train)
#       4     ypred = model.predict(X_test)
#       6     print(confusion_matrix(y_test, ypred))
#
# File C:\ProgramData\anaconda3\envs\Projet7\Lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File C:\ProgramData\anaconda3\envs\Projet7\Lib\site-packages\sklearn\tree\_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     184 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186 X, y = self._validate_data(
#     187     X, y, validate_separately=(check_X_params, check_y_params)
#     188 )
#     189 if issparse(X):
#     190     X.sort_indices()
#
# File C:\ProgramData\anaconda3\envs\Projet7\Lib\site-packages\sklearn\base.py:579, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     577 if "estimator" not in check_X_params:
#     578     check_X_params = {**default_check_params, **check_X_params}
# --> 579 X = check_array(X, input_name="X", **check_X_params)
#     580 if "estimator" not in check_y_params:
#     581     check_y_params = {**default_check_params, **check_y_params}
#
# File C:\ProgramData\anaconda3\envs\Projet7\Lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File C:\ProgramData\anaconda3\envs\Projet7\Lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# DecisionTreeClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
estimator = DummyClassifier(strategy='most_frequent')
estimator.fit(X_train, y_train)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
y_pred = estimator.predict(X_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 y_pred = estimator.predict(X_test)
#       2 y_pred
#
# NameError: name 'X_test' is not defined

# %%
pd.Series(y_pred).value_counts()

# %%
y_test.value_counts(normalize=True)

# %%
y_test.values

# %%
def score(estimator):
    """Calcule et édite les scores train et test"""
    
    tr_score = estimator.score(X_train, y_train).round(4)
    te_score = estimator.score(X_test, y_test).round(4)
    
    print(f"score train : {tr_score} score test : {te_score}")

# %%
score(estimator)

# %%
pd.Series(y_train).value_counts(normalize=True).round(4)

# %%
pd.Series(y_test).value_counts(normalize=True).round(4)

# %%
def confusion(y_test, y_pred):
    """Affiche la matrice de confusion"""
    
    mat = confusion_matrix(y_test, y_pred)
    mat=pd.DataFrame(mat)
    mat.columns = [f"pred_{i}" for i in mat.columns]
    mat.index = [f"test_{i}" for i in mat.index]
    
    return mat

# %%
confusion(y_test, y_pred)

# %%
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, color='red', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Simple Logistic regression & Linear SVM
# ### Logistic Regression

# %%
estimator = LogisticRegression(solver="liblinear")
estimator.fit(X_train, y_train)

# %%
y_pred = estimator.predict(X_test)
y_pred

# %%
y_prob = estimator.predict_proba(X_test).round(2)
y_prob

# %%
estimator = LinearSVC()
estimator.fit(X_train, y_train)

# %%
df.isna().mean().sort_values(ascending=False).tolist()
